# %%
import cv2
import matplotlib.pyplot as plt
quesn=cv2.imread("Q_4_Coin_Pair_Indices.png")
# 2. Set the display size (width, height in inches)
plt.figure(figsize=(200, 200))
plt.imshow(quesn)

# %% [markdown]
# # This is the proxy of the "Two Sum" Problem

# %%
def coin_pairs(coins,target_sum):
    seen={}
    for idx,num in enumerate(coins):
        complement=target_sum-num
        if complement in seen:
            return [seen[complement],idx]
        else:
            seen[num]=idx
    return -1

coins=list(map(int,input().split()))
target_sum=int(input())
print(coin_pairs(coins,target_sum))
