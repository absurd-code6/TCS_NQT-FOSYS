# %%
import cv2
import matplotlib.pyplot as plt
quesn=cv2.imread("Q_4_Delhi_Pollution.png")
# 2. Set the display size (width, height in inches)
plt.figure(figsize=(200, 200))
plt.imshow(quesn)
plt.show()  # Optional, but good practice to cleanly render the plot

# %%
#Read N elements for the array, each on a new line
N = int(input())
vehicles = []
for _ in range(N):
    vehicles.append(int(input()))
#Read the date D and the fine amount X
D = int(input())
X = int(input())
if D%2==0:
    even=1
else:
    even=0
Violators=[]
fine=0
for i in vehicles:
    if i%2==0:
        if not even:
         Violators.append(i)
        elif even:
            continue
    else:
        if even:
            Violators.append(i)
        elif not even:
            continue

for j in Violators:
    fine+=X
print(fine)
