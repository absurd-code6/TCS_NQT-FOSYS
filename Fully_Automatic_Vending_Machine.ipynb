# %%
import cv2
import matplotlib.pyplot as plt
quesn=cv2.imread("Q_4_Fully_Automatic_Vending_Machine_1.png")
# 2. Set the display size (width, height in inches)
plt.figure(figsize=(100, 100))
plt.imshow(quesn)

# %%
quesn1=cv2.imread("Q_4_Fully_Automatic_Vending_Machine_2.png")
# 2. Set the display size (width, height in inches)
plt.figure(figsize=(100, 100))
plt.imshow(quesn1)

# %%
first_letter = input().lower()
menu=["c","t","s","b"]
#for i in main_menu:
    #if i != first_letter:
        #print("INVALID INPUT")
'''Why the loop doesn't work
Suppose the user enters

c
Dry Run
Iteration	i	first_letter	Condition i != first_letter	Output
1	c	c	False	Nothing
2	t	c	True	INVALID INPUT
3	s	c	True	INVALID INPUT
4	b	c	True	INVALID INPUT

Output

INVALID INPUT
INVALID INPUT
INVALID INPUT

This is wrong because c is a valid choice.

The loop checks every element one by one. Even if one element matches, 
the remaining elements don't, so "INVALID INPUT" gets 
printed several times.

How to make the loop work

found = False

for i in main_menu:
    if i == first_letter:
        found = True

if found == False:
    print("INVALID INPUT")'''

menu_list = {
    "c": {
        1: "Espresso Coffee",
        2: "Cappuccino Coffee",
        3: "Latte Coffee"
    },

    "t": {
        1: "Plain Tea",
        2: "Assam Tea",
        3: "Ginger Tea",
        4: "Cardamom Tea",
        5: "Masala Tea",
        6: "Lemon Tea",
        7: "Green Tea",
        8: "Organic Darjeeling Tea"
    },

    "s": {
        1: "Hot and Sour Soup",
        2: "Veg Corn Soup",
        3: "Tomato Soup",
        4: "Spicy Tomato Soup"
    },

    "b": {
        1: "Hot Chocolate Drink",
        2: "Badam Drink",
        3: "Badam-Pista Drink"
    }
}

if first_letter not in menu_list:
    print("INVALID INPUT")
else:
    option = int(input())

if option not in menu_list[first_letter]:
    print("INVALID INPUT")
else:
    print("Welcome to CCD!")
    print("Enjoy your", menu_list[first_letter][option] + "!")
# Out:
# Welcome to CCD!
# Enjoy your Hot Chocolate Drink!

# %%
'''Understanding the dictionary

For example,

menu["c"]

returns

{
    1: "Espresso Coffee",
    2: "Cappuccino Coffee",
    3: "Latte Coffee"
}

Similarly,

menu["t"][5]

returns

"Masala Tea"

The first [] selects the main menu, and the second [] selects the submenu.

Step 4: Check whether the main menu is valid
first_letter = input().lower()

if first_letter not in menu:
    print("INVALID INPUT")
Dry Run

Input

c

Check

"c" not in menu

Result

False

So the program continues.

Input

x

Check

"x" not in menu

Result

True

Output

INVALID INPUT
Step 5: Read the submenu choice

If the main menu is valid, ask for the submenu number.

else:
    option = int(input())

Example

Input

c
1

Now

first_letter = "c"
option = 1
Step 6: Check whether the submenu number is valid
    if option not in menu[first_letter]:
        print("INVALID INPUT")
Dry Run

Input

c
5

The submenu is

menu["c"]

which is

{
    1:"Espresso Coffee",
    2:"Cappuccino Coffee",
    3:"Latte Coffee"
}

Check

5 not in menu["c"]

Result

True

Output

INVALID INPUT
Step 7: Print the selected item

If both inputs are valid,

    else:
        print("Welcome to CCD!")
        print("Enjoy your", menu[first_letter][option] + "!")
Dry Run

Input

c
1

Variables

first_letter = "c"
option = 1

The statement

menu[first_letter][option]

becomes

menu["c"][1]

which returns

Espresso Coffee

Output

Welcome to CCD!
Enjoy your Espresso Coffee!'''
