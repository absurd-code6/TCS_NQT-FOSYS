# %%
import cv2
import matplotlib.pyplot as plt
quesn=cv2.imread("Q_4_Reversing_Digits.png")
# 2. Set the display size (width, height in inches)
plt.figure(figsize=(100, 100))
plt.imshow(quesn)

# %%
n=int(input())
rev=0
while n>0:
    r=n%10
    rev=rev*10 + r
    n//=10 # Make sure its floor division & not float division
print(rev)
#   OR
N=input()
print(int(N[::-1]))
# Out:
# 49
# 54
